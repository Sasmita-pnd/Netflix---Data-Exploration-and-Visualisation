# %% [markdown]
# ### Problem Statement

# %% [markdown]
#  Given Netflix Dataset our aim is to analyze the data and generate insights that could help in deciding which type of shows or movies to produce and how they can grow the business in different countries.

# %% [markdown]
# ### Basic Analysis

# %% [markdown]
# First we will import the required libraries and then read the dataset

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
netflix_titles=pd.read_csv(r'D:\SQL\Data Analytics\netflix_titles.csv')

# %%
netflix_titles
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix_titles.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix_titles.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# ## 2. Observations on the shape of data, data types of all the attributes, conversion of categorical attributes to 'category' (If required), missing value detection, statistical summary

# %%
netflix_titles.shape
# Out:
# (8807, 12)

# %%
netflix_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# Attribute release_year is of int datatype and rest all attributes are of object datatype

# %% [markdown]
# ### Categorical Attributes

# %% [markdown]
# country or type column can be converted to category

# %%
netflix_titles["type"]=netflix_titles["type"].astype("category")

# %%
netflix_titles["type"]
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802      Movie
# 8803    TV Show
# 8804      Movie
# 8805      Movie
# 8806      Movie
# Name: type, Length: 8807, dtype: category
# Categories (2, object): [Movie, TV Show]

# %% [markdown]
# From above we can observe that only two types of shows are produced that is Movies and TV show

# %%
sns.heatmap(netflix_titles.isna())

# %% [markdown]
# From above we can say that director column has a lot of missing data followed by cast and  country column and other colums with null values are date_added,release_year,rating and duration

# %%
netflix_titles.describe(include="all")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c3886798c197> in <module>
# ----> 1 netflix_titles.describe(include="all")
#
# NameError: name 'netflix_titles' is not defined

# %% [markdown]
# ### Un-nesting the columns

# %%
director = netflix_titles['director'].str.split(', ', expand=True).stack()
director
# Out:
# 0     0    Kirsten Johnson
# 2     0    Julien Leclercq
# 5     0      Mike Flanagan
# 6     0      Robert Cullen
#       1     José Luis Ucha
#                 ...
# 8801  0    Majid Al Ansari
# 8802  0      David Fincher
# 8804  0    Ruben Fleischer
# 8805  0       Peter Hewitt
# 8806  0        Mozez Singh
# Length: 6978, dtype: object

# %%
director = director.reset_index(level=1, drop=True).to_frame('director')
director
# Out:
#              director
# 0     Kirsten Johnson
# 2     Julien Leclercq
# 5       Mike Flanagan
# 6       Robert Cullen
# 6      José Luis Ucha
# ...               ...
# 8801  Majid Al Ansari
# 8802    David Fincher
# 8804  Ruben Fleischer
# 8805     Peter Hewitt
# 8806      Mozez Singh
#
# [6978 rows x 1 columns]

# %%
director['show_id'] = netflix_titles['show_id']
director
# Out:
#              director show_id
# 0     Kirsten Johnson      s1
# 2     Julien Leclercq      s3
# 5       Mike Flanagan      s6
# 6       Robert Cullen      s7
# 6      José Luis Ucha      s7
# ...               ...     ...
# 8801  Majid Al Ansari   s8802
# 8802    David Fincher   s8803
# 8804  Ruben Fleischer   s8805
# 8805     Peter Hewitt   s8806
# 8806      Mozez Singh   s8807
#
# [6978 rows x 2 columns]

# %%
cast = netflix_titles['cast'].str.split(', ', expand=True).stack()
cast =cast.reset_index(level=1, drop=True).to_frame('cast')
cast['show_id'] =netflix_titles['show_id']
cast
# Out:
#                        cast show_id
# 1                Ama Qamata      s2
# 1               Khosi Ngema      s2
# 1             Gail Mabalane      s2
# 1            Thabang Molaba      s2
# 1          Dillon Windvogel      s2
# ...                     ...     ...
# 8806       Manish Chaudhary   s8807
# 8806           Meghna Malik   s8807
# 8806          Malkeet Rauni   s8807
# 8806         Anita Shabdish   s8807
# 8806  Chittaranjan Tripathy   s8807
#
# [64126 rows x 2 columns]

# %%
country = netflix_titles['country'].str.split(', ', expand=True).stack()
country = country.reset_index(level=1, drop=True).to_frame('country')
country['show_id'] = netflix_titles['show_id']
country
# Out:
#             country show_id
# 0     United States      s1
# 1      South Africa      s2
# 4             India      s5
# 7     United States      s8
# 7             Ghana      s8
# ...             ...     ...
# 8801         Jordan   s8802
# 8802  United States   s8803
# 8804  United States   s8805
# 8805  United States   s8806
# 8806          India   s8807
#
# [10014 rows x 2 columns]

# %%
listed_in =netflix_titles['listed_in'].str.split(', ', expand=True).stack()
listed_in = listed_in.reset_index(level=1, drop=True).to_frame('listed_in')
listed_in['show_id'] = netflix_titles['show_id']
listed_in
# Out:
#                      listed_in show_id
# 0                Documentaries      s1
# 1       International TV Shows      s2
# 1                    TV Dramas      s2
# 1                 TV Mysteries      s2
# 2               Crime TV Shows      s3
# ...                        ...     ...
# 8805  Children & Family Movies   s8806
# 8805                  Comedies   s8806
# 8806                    Dramas   s8807
# 8806      International Movies   s8807
# 8806          Music & Musicals   s8807
#
# [19323 rows x 2 columns]

# %%
netflix_titles=netflix_titles.merge(director,on="show_id")
netflix_titles
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 1         s3  TV Show                         Ganglands
# 2         s6  TV Show                     Midnight Mass
# 3         s7    Movie  My Little Pony: A New Generation
# 4         s7    Movie  My Little Pony: A New Generation
# ...      ...      ...                               ...
# 6973   s8802    Movie                           Zinzana
# 6974   s8803    Movie                            Zodiac
# 6975   s8805    Movie                        Zombieland
# 6976   s8806    Movie                              Zoom
# 6977   s8807    Movie                            Zubaan
#
#                          director_x  \
# 0                   Kirsten Johnson
# 1                   Julien Leclercq
# 2                     Mike Flanagan
# 3     Robert Cullen, José Luis Ucha
# 4     Robert Cullen, José Luis Ucha
# ...                             ...
# ...

# %%
netflix_titles=netflix_titles.merge(cast,on="show_id")
netflix_titles
# Out:
#       show_id     type      title       director_x  \
# 0          s3  TV Show  Ganglands  Julien Leclercq
# 1          s3  TV Show  Ganglands  Julien Leclercq
# 2          s3  TV Show  Ganglands  Julien Leclercq
# 3          s3  TV Show  Ganglands  Julien Leclercq
# 4          s3  TV Show  Ganglands  Julien Leclercq
# ...       ...      ...        ...              ...
# 51186   s8807    Movie     Zubaan      Mozez Singh
# 51187   s8807    Movie     Zubaan      Mozez Singh
# 51188   s8807    Movie     Zubaan      Mozez Singh
# 51189   s8807    Movie     Zubaan      Mozez Singh
# 51190   s8807    Movie     Zubaan      Mozez Singh
#
#                                                   cast_x country  \
# 0      Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN
# 1      Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN
# 2      Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN
# 3      Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN
# ...

# %%
netflix_titles=netflix_titles.merge(country,on="show_id")
netflix_titles
# Out:
#       show_id   type    title    director_x  \
# 0          s8  Movie  Sankofa  Haile Gerima
# 1          s8  Movie  Sankofa  Haile Gerima
# 2          s8  Movie  Sankofa  Haile Gerima
# 3          s8  Movie  Sankofa  Haile Gerima
# 4          s8  Movie  Sankofa  Haile Gerima
# ...       ...    ...      ...           ...
# 63522   s8807  Movie   Zubaan   Mozez Singh
# 63523   s8807  Movie   Zubaan   Mozez Singh
# 63524   s8807  Movie   Zubaan   Mozez Singh
# 63525   s8807  Movie   Zubaan   Mozez Singh
# 63526   s8807  Movie   Zubaan   Mozez Singh
#
#                                                   cast_x  \
# 0      Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 1      Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 2      Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 3      Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 4      Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# ...                                                  ...
# ...

# %%
netflix_titles=netflix_titles.merge(listed_in,on="show_id")
netflix_titles
# Out:
#        show_id   type    title    director_x  \
# 0           s8  Movie  Sankofa  Haile Gerima
# 1           s8  Movie  Sankofa  Haile Gerima
# 2           s8  Movie  Sankofa  Haile Gerima
# 3           s8  Movie  Sankofa  Haile Gerima
# 4           s8  Movie  Sankofa  Haile Gerima
# ...        ...    ...      ...           ...
# 143097   s8807  Movie   Zubaan   Mozez Singh
# 143098   s8807  Movie   Zubaan   Mozez Singh
# 143099   s8807  Movie   Zubaan   Mozez Singh
# 143100   s8807  Movie   Zubaan   Mozez Singh
# 143101   s8807  Movie   Zubaan   Mozez Singh
#
#                                                    cast_x  \
# 0       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 1       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 2       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 3       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 4       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# ...                                                   ...
# ...

# %%
netflix_titles=netflix_titles.drop(["director_x","cast_x","country_x","listed_in_x"],axis=1)

# %%
netflix_titles
# Out:
#        show_id   type    title          date_added  release_year rating  \
# 0           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 1           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 2           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 3           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 4           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# ...        ...    ...      ...                 ...           ...    ...
# 143097   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143098   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143099   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143100   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143101   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
#
#        duration                                        description  \
# ...

# %% [markdown]
# ### Handling null values

# %%
netflix_titles.isna().any()
# Out:
# show_id         False
# type            False
# title           False
# date_added      False
# release_year    False
# rating           True
# duration         True
# description     False
# director_y      False
# cast_y          False
# country_y       False
# listed_in_y     False
# dtype: bool

# %%
netflix_titles.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# date_added      0
# release_year    0
# rating          7
# duration        3
# description     0
# director_y      0
# cast_y          0
# country_y       0
# listed_in_y     0
# dtype: int64

# %% [markdown]
# we can observe that columns rating and duration has missing values

# %%
netflix_titles["rating"].fillna(value="unknown rating",inplace=True)

# %%
netflix_titles["duration"].fillna(value="unknown duration",inplace=True)

# %%
netflix_titles.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# date_added      0
# release_year    0
# rating          0
# duration        0
# description     0
# director_y      0
# cast_y          0
# country_y       0
# listed_in_y     0
# dtype: int64

# %%
Now all the null values have been taken care of.

# %% [markdown]
# ###  Non-Graphical and Visual Analysis

# %% [markdown]
# #### Comparison of tv shows vs. movies.

# %% [markdown]
# number of movies produced in each country and  top 10 countries

# %%
movies_produced=netflix_titles.loc[netflix_titles["type"]=="Movie",["country_y"]]

# %%
movies_produced["country_y"].value_counts()
# Out:
# United States     44879
# India             21268
# United Kingdom     8396
# France             6553
# Canada             5627
#                   ...
# Vatican City          3
# Panama                2
# Sri Lanka             2
# Afghanistan           2
# Nicaragua             1
# Name: country_y, Length: 113, dtype: int64

# %%
movies_produced["country_y"].value_counts().head(10)
# Out:
# United States     44879
# India             21268
# United Kingdom     8396
# France             6553
# Canada             5627
# Japan              3511
# Spain              3403
# Germany            3390
# China              2351
# Nigeria            2231
# Name: country_y, dtype: int64

# %%
sns.countplot(data=movies_produced,y="country_y",order=movies_produced["country_y"].value_counts().index[0:10])
plt.title("top 10 countries in movie production")
# Out:
# Text(0.5, 1.0, 'top 10 countries in movie production')

# %% [markdown]
# ###### Insight

# %% [markdown]
# There are total 748 countries out of which 651 are involved in Movie production.
# Highest number of movies were produced by United States  that is 44879 and lowest number of movies were produced by Nicaragua that is 1 movie
# In the top 10 countries in movie production highest position is occupied by United States and Nigeria is at position number 10

# %% [markdown]
# number of Tv-Shows produced in each country and the top 10 countries

# %%
top10_tv=netflix_titles.loc[netflix_titles["type"]=="TV Show",["country_y"]]

# %%
top10_tv["country_y"].value_counts()
# Out:
# United States     894
# United Kingdom    596
# Taiwan            495
# India             494
# South Korea       358
# Spain             357
# Japan             307
# Thailand          285
# France            263
# Canada            166
# Turkey            150
# Colombia          147
# Mexico            129
# Nigeria           110
# Germany           107
# Brazil            102
# Italy              86
# Ireland            78
# Philippines        63
# Saudi Arabia       50
# China              48
# Belgium            42
# Denmark            41
# Malaysia           30
# Russia             30
# Poland             30
# Singapore          27
# Indonesia          27
# Pakistan           18
# Australia          14
# Argentina           9
# Greece              3
# Israel              2
# South Africa        2
# Name: country_y, dtype: int64

# %%
top10_tv["country_y"].value_counts().head(10)
# Out:
# United States     894
# United Kingdom    596
# Taiwan            495
# India             494
# South Korea       358
# Spain             357
# Japan             307
# Thailand          285
# France            263
# Canada            166
# Name: country_y, dtype: int64

# %%
sns.countplot(data=top10_tv,y="country_y",order=top10_tv["country_y"].value_counts().index[0:10])
plt.title("top 10 countries in TV Shows production")
# Out:
# Text(0.5, 1.0, 'top 10 countries in TV Shows production')

# %% [markdown]
# #### Insight

# %% [markdown]
# There are total 748 countries out of which only 196 are involved in TV Show Production
# Highest number of TV Shows were produced by United States  that is 894 and lowest number of movies were produced by South Africa that is 2
# In the top 10 countries in TV Show production highest position is occupied by United States and Canada  is at position number 10

# %% [markdown]
#  Best time to launch a TV show or Movie

# %%
netflix_titles["week"] = pd.to_datetime(netflix_titles["date_added"]).dt.week

# %%
netflix_titles
# Out:
#        show_id   type    title          date_added  release_year rating  \
# 0           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 1           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 2           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 3           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 4           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# ...        ...    ...      ...                 ...           ...    ...
# 143097   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143098   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143099   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143100   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143101   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
#
#        duration                                        description  \
# ...

# %%
dfmovies = netflix_titles[netflix_titles["type"] == "Movie"]
dftv = netflix_titles[netflix_titles["type"] == "TV Show"]

# %%
movies_count = dfmovies["week"].value_counts()

# %%
movies_count
# Out:
# 1     8136
# 44    5412
# 9     4888
# 35    4850
# 40    4722
# 26    4659
# 31    4283
# 48    3576
# 18    3567
# 27    3497
# 13    3395
# 39    3350
# 22    3109
# 23    3082
# 5     3043
# 30    3003
# 15    2952
# 14    2533
# 7     2496
# 43    2457
# 10    2407
# 36    2403
# 37    2390
# 28    2389
# 17    2360
# 25    2337
# 50    2332
# 51    2170
# 16    2154
# 11    2122
# 34    2100
# 49    2074
# 33    2061
# 42    2015
# 3     1982
# 29    1935
# 38    1906
# 52    1784
# 41    1754
# 47    1734
# 20    1674
# 6     1607
# 2     1579
# 24    1499
# 46    1456
# 8     1451
# 19    1432
# 12    1385
# 45    1372
# 21    1370
# 53    1307
# 32    1031
# 4      960
# Name: week, dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.countplot(data=dfmovies,x="week")
plt.title("number of movies launched in weeks")
# Out:
# Text(0.5, 1.0, 'number of movies launched in weeks')

# %% [markdown]
# #### Insight

# %% [markdown]
# There are total 53 weeks.
#
# Highest number of Movies were launched first week of the year that is 8136 and lowest number of movies were lainched in fourth week of the year.

# %%
tvshows_count = dftv["week"].value_counts()
tvshows_count
# Out:
# 19    460
# 7     309
# 51    289
# 5     288
# 31    245
# 33    228
# 15    220
# 13    209
# 44    193
# 38    182
# 27    181
# 23    173
# 24    166
# 49    155
# 18    141
# 10    124
# 42    123
# 34    123
# 25    117
# 4     117
# 3     112
# 40    102
# 1      96
# 32     91
# 22     80
# 50     78
# 20     77
# 46     65
# 11     60
# 21     59
# 35     58
# 43     57
# 37     55
# 28     51
# 52     50
# 9      50
# 48     40
# 2      39
# 6      34
# 41     33
# 30     33
# 39     33
# 45     30
# 26     30
# 16     27
# 12     23
# 8      19
# 53     15
# 36     12
# 17      5
# 29      3
# Name: week, dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.countplot(data=dftv,x="week")
plt.title("number of TV Shows launched in weeks")
# Out:
# Text(0.5, 1.0, 'number of TV Shows launched in weeks')

# %% [markdown]
# #### Insight

# %% [markdown]
# There are total 53 weeks.
#
# Highest number of TV Shows were launched nineteenth week of the year that is 460 and lowest number of TV Shows were launched in 29th week of the year i.e 3

# %% [markdown]
# Best month to release the Tv-show

# %%
netflix_titles["month"] = pd.to_datetime(netflix_titles["date_added"]).dt.month_name()

# %%
netflix_titles
# Out:
#        show_id   type    title          date_added  release_year rating  \
# 0           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 1           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 2           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 3           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 4           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# ...        ...    ...      ...                 ...           ...    ...
# 143097   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143098   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143099   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143100   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143101   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
#
#        duration                                        description  \
# ...

# %%
dfmovies_month = netflix_titles[netflix_titles["type"] == "Movie"]
dftv_month = netflix_titles[netflix_titles["type"] == "TV Show"]

# %%
movies_month_count = dfmovies_month["month"].value_counts()

# %%
movies_month_count
# Out:
# July         13623
# January      13449
# October      13143
# September    12393
# December     12169
# April        11864
# March        11025
# August       10943
# November     10742
# June         10627
# May           8800
# February      8764
# Name: month, dtype: int64

# %%
sns.countplot(data=dfmovies_month,y="month")
plt.title("number of movies launched in months")
# Out:
# Text(0.5, 1.0, 'number of movies launched in months')

# %% [markdown]
# #### Insight

# %% [markdown]
# There are total 12 months
#
# Highest number of movies were launched july that is 13623 and lowest number of movies were launched in February i.e 8764

# %%
tv_month_count = dftv_month["month"].value_counts()

# %%
tv_month_count
# Out:
# February     700
# August       679
# May          670
# December     588
# June         510
# October      445
# March        416
# September    382
# January      379
# April        345
# July         306
# November     140
# Name: month, dtype: int64

# %%
sns.countplot(data=dftv_month,y="month")
plt.title("number of TV Shows launched in months")
# Out:
# Text(0.5, 1.0, 'number of TV Shows launched in months')

# %% [markdown]
# #### Insight

# %% [markdown]
# There are total 12 months
#
# Highest number of TV Shows were launched February i.e 700 and lowest  were launched in November i.e 140

# %% [markdown]
# Analysis of actors/directors of different types of shows/movies.

# %%
netflix_titles.drop_duplicates()
# Out:
#        show_id   type    title          date_added  release_year rating  \
# 0           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 1           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 2           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 3           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# 4           s8  Movie  Sankofa  September 24, 2021          1993  TV-MA
# ...        ...    ...      ...                 ...           ...    ...
# 143097   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143098   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143099   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143100   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
# 143101   s8807  Movie   Zubaan       March 2, 2019          2015  TV-14
#
#        duration                                        description  \
# ...

# %%
actors_movie=netflix_titles.loc[netflix_titles["type"]=="Movie",["cast_y"]]

# %%
actors_movie["cast_y"].value_counts()
# Out:
# Liam Neeson       161
# Alfred Molina     154
# John Krasinski    138
# Salma Hayek       130
# Frank Langella    128
#                  ...
# Jason Dolley        1
# Luke Tennie         1
# Janet Jackson       1
# RonReaco Lee        1
# Colin Moy           1
# Name: cast_y, Length: 24619, dtype: int64

# %%
actors_movie["cast_y"].value_counts().head(10)
# Out:
# Liam Neeson          161
# Alfred Molina        154
# John Krasinski       138
# Salma Hayek          130
# Frank Langella       128
# Anupam Kher          118
# John Rhys-Davies     116
# Shah Rukh Khan       107
# Naseeruddin Shah     103
# Quvenzhané Wallis    100
# Name: cast_y, dtype: int64

# %%
sns.countplot(data=actors_movie,y="cast_y",order=actors_movie["cast_y"].value_counts().index[0:10])
plt.title("top 10 Movie actors by title")
# Out:
# Text(0.5, 1.0, 'top 10 Movie actors by title')

# %% [markdown]
# #### Insight

# %% [markdown]
# There are total 24619 actors
# Highest number of movies were acted in by Liam Neeson i.e 161 movies and lowest number of movies were acted by Colin Moy i.e  1 movie
# In the top 10 actors in movie  highest position is occupied by Liam Neeson and Quvenzhané Wallis  is at position number 10

# %%
actors_tv=netflix_titles.loc[netflix_titles["type"]=="TV Show",["cast_y"]]

# %%
actors_tv["cast_y"].value_counts()
# Out:
# Tchéky Karyo             32
# Randy Kerber             32
# Joanna Kulig             32
# André Holland            32
# Adil Dehbi               32
#                          ..
# Aditi Arya                1
# Rebecca Dayan             1
# George Plimpton           1
# Gian Franco Rodriguez     1
# Horton Foote              1
# Name: cast_y, Length: 1324, dtype: int64

# %%
actors_tv["cast_y"].value_counts().head(10)
# Out:
# Tchéky Karyo           32
# Randy Kerber           32
# Joanna Kulig           32
# André Holland          32
# Adil Dehbi             32
# Elyes Aguis            32
# Leïla Bekhti           32
# Benjamin Biolay        32
# Damian Nueva Cortes    32
# Melissa George         32
# Name: cast_y, dtype: int64

# %%
sns.countplot(data=actors_tv,y="cast_y",order=actors_tv["cast_y"].value_counts().index[0:10])
plt.title("top 10 TV Show actors by title")
# Out:
# Text(0.5, 1.0, 'top 10 TV Show actors by title')

# %% [markdown]
# #### Insight

# %% [markdown]
# There are total 1324 actors acting in TV Shows
# Highest number of shows were acted in by Tchéky Karyo i.e 32 Shows and lowest number of shows were acted by Horton Foote  i.e  1
# In the top 10 actors  all the 10 actors have acted in 32 TV Shows

# %%
director_tv=netflix_titles.loc[netflix_titles["type"]=="TV Show",["director_y"]]

# %%
director_movie=netflix_titles.loc[netflix_titles["type"]=="Movie",["director_y"]]

# %%
director_tv["director_y"].value_counts()
# Out:
# Noam Murro         189
# Thomas Astruc      160
# Laïla Marrakchi    104
# Houda Benyamina    104
# Damien Chazelle    104
#                   ...
# Mick Grogan          2
# Glenn Weiss          1
# Oliver Stone         1
# Eric Abrams          1
# Michael Simon        1
# Name: director_y, Length: 191, dtype: int64

# %%
director_tv["director_y"].value_counts().head(10)
# Out:
# Noam Murro          189
# Thomas Astruc       160
# Laïla Marrakchi     104
# Houda Benyamina     104
# Damien Chazelle     104
# Alan Poul           104
# Rob Seidenglanz     103
# Alejandro Lozano     90
# Jay Oliva            81
# Manolo Caro          78
# Name: director_y, dtype: int64

# %%
sns.countplot(data=director_tv,y="director_y",order=director_tv["director_y"].value_counts().index[0:10])
plt.title("top 10 TV Show director ")
# Out:
# Text(0.5, 1.0, 'top 10 TV Show director ')

# %% [markdown]
# #### Insights

# %% [markdown]
# There are total 191 directors  in TV Shows
# Highest number of shows were directed by Noam Murro i.e 189 Shows and lowest number of shows were directed by Michael Simon  i.e  1
# In the top 10 directors  top position is occupied by Noam Murro  and 10th position by Manolo Caro

# %%
director_movie["director_y"].value_counts()
# Out:
# Martin Scorsese        419
# Youssef Chahine        409
# Cathy Garcia-Molina    356
# Steven Spielberg       355
# Lars von Trier         336
#                       ...
# Dylan Bank               1
# Mariano Baez             1
# Daniel DiMauro           1
# Jake Paltrow             1
# Josh Koury               1
# Name: director_y, Length: 4169, dtype: int64

# %%
director_movie["director_y"].value_counts().head(10)
# Out:
# Martin Scorsese        419
# Youssef Chahine        409
# Cathy Garcia-Molina    356
# Steven Spielberg       355
# Lars von Trier         336
# Raja Gosnell           308
# Tom Hooper             306
# McG                    293
# David Dhawan           270
# Wilson Yip             260
# Name: director_y, dtype: int64

# %%
sns.countplot(data=director_movie,y="director_y",order=director_movie["director_y"].value_counts().index[0:10])
plt.title("top 10 movie director ")
# Out:
# Text(0.5, 1.0, 'top 10 movie director ')

# %% [markdown]
# #### Insights

# %% [markdown]
# There are total 4169 directors  in Movies
# Highest number of shows were directed by Martin Scorsese i.e 419 Shows and lowest number of shows were directed by Josh Koury,Jake Paltrow,Daniel DiMauro etc.   i.e  1
# In the top 10 directors  top position is occupied by Martin Scorsese  and 10th position by Wilson Yip

# %% [markdown]
# Which genre movies are more popular or produced more

# %%
genredf=netflix_titles.loc[netflix_titles["type"]=="Movie",["listed_in_y"]]

# %%
genredf["listed_in_y"].value_counts()
# Out:
# Dramas                      28698
# International Movies        26191
# Comedies                    19834
# Action & Adventure          11761
# Independent Movies           9712
# Children & Family Movies     8796
# Thrillers                    6857
# Romantic Movies              6145
# Horror Movies                4416
# Sci-Fi & Fantasy             3980
# Music & Musicals             2717
# Documentaries                1492
# Classic Movies               1407
# Sports Movies                1389
# Cult Movies                  1071
# Anime Features                934
# LGBTQ Movies                  769
# Faith & Spirituality          699
# Stand-Up Comedy               443
# Movies                        231
# Name: listed_in_y, dtype: int64

# %%
sns.countplot(data=genredf,y="listed_in_y")
plt.title(" movie genre in decreasing order of popularity ")
# Out:
# Text(0.5, 1.0, ' movie genre in decreasing order of popularity ')

# %% [markdown]
# #### Insight

# %% [markdown]
# There are total 20 genres  in Movies
# Most popular genre is Drama and least popular genre is movies

# %%
netflix_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 143102 entries, 0 to 143101
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       143102 non-null  object
#  1   type          143102 non-null  category
#  2   title         143102 non-null  object
#  3   date_added    143102 non-null  object
#  4   release_year  143102 non-null  int64
#  5   rating        143102 non-null  object
#  6   duration      143102 non-null  object
#  7   description   143102 non-null  object
#  8   director_y    143102 non-null  object
#  9   cast_y        143102 non-null  object
#  10  country_y     143102 non-null  object
#  11  listed_in_y   143102 non-null  object
#  12  week          143102 non-null  int64
#  13  month         143102 non-null  object
# dtypes: category(1), int64(2), object(11)
# memory usage: 15.4+ MB

# %%
netflix_titles[["date_added","release_year"]] = netflix_titles[["date_added","release_year"]].apply(pd.to_datetime)
netflix_titles["days"] = (netflix_titles["date_added"] - netflix_titles["release_year"]).dt.days

# %%
netflix_titles
# Out:
#        show_id   type    title date_added                  release_year  \
# 0           s8  Movie  Sankofa 2021-09-24 1970-01-01 00:00:00.000001993
# 1           s8  Movie  Sankofa 2021-09-24 1970-01-01 00:00:00.000001993
# 2           s8  Movie  Sankofa 2021-09-24 1970-01-01 00:00:00.000001993
# 3           s8  Movie  Sankofa 2021-09-24 1970-01-01 00:00:00.000001993
# 4           s8  Movie  Sankofa 2021-09-24 1970-01-01 00:00:00.000001993
# ...        ...    ...      ...        ...                           ...
# 143097   s8807  Movie   Zubaan 2019-03-02 1970-01-01 00:00:00.000002015
# 143098   s8807  Movie   Zubaan 2019-03-02 1970-01-01 00:00:00.000002015
# 143099   s8807  Movie   Zubaan 2019-03-02 1970-01-01 00:00:00.000002015
# 143100   s8807  Movie   Zubaan 2019-03-02 1970-01-01 00:00:00.000002015
# 143101   s8807  Movie   Zubaan 2019-03-02 1970-01-01 00:00:00.000002015
#
#        rating duration                                        description  \
# ...

# %%
netflix_titles["days"].mode()
# Out:
# 0    18261
# dtype: int64

# %%
sns.boxplot(data=netflix_titles, x="days")

# %% [markdown]
# #### Insights

# %% [markdown]
# A better time to add in netflix is to add a show after 18261 days

# %% [markdown]
# #### Does Netflix has more focus on TV Shows than movies in recent years

# %%
netflix_titles["type"] = netflix_titles["type"].astype('string')

# %%
netflix_titles["type"].value_counts()
# Out:
# Movie      137542
# TV Show      5560
# Name: type, dtype: Int64

# %% [markdown]
# #### Insights

# %% [markdown]
# We can see that Netflix has more focus on movies.

# %% [markdown]
# ### Business Insights

# %% [markdown]
# 1. Netflix is more focussed on movies launch.
# 2. Netflix takes an average of 18261 days to launch a show
# 3. Netflix has most of the content made in United States.
# 4. Netflix has more content on drama compared to other genres
# 5. Movie actors have more number of shows they aced on compared to TV Shows  actors

# %% [markdown]
# ### Recommendations

# %% [markdown]
# 1. Netflis should increase its focus in adding more TV Shows to platform.
# 2. Netflix should focus on getting more content  from other countries as well compared to top 10 countries.
# 3. Netflis should also focus on adding content of genres other than dramas.
# 4. Netflix can maybe try to launch more shows in months and weeks when lowest number of shows are launched.
